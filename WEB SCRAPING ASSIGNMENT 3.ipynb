# %% [markdown]
# # WEB SCRAPING ASSIGNMENT 3

# %%
# !pip install selenium

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # Q1. all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user.

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = 'https://amazon.in'
driver.get(url)

# %%
search = driver.find_element_by_id('twotabsearchtextbox')
user_inp = input('Enter the product you want to search : ')  
search.send_keys(user_inp)
# Out:
# Enter the product you want to search : tops

# %%
btn = driver.find_element_by_id('nav-search-submit-button')
btn.click()

# %% [markdown]
# ## Q2

# %%
start_page = 0

end_page = 3

urls = []

for page in range(start_page,end_page+1):

    try:

        page_urls = driver.find_elements_by_xpath('//span[@class="a-size-base-plus a-color-base"]')

        

        # appending all the urls on current page to urls list

        for url in page_urls:

            url = url.get_attribute('href')     # Scraping the url from webelement

            if url[0:4]=='https':                # Checking if the scraped data is a valid url or not

                urls.append(url)                # Appending the url to urls list

        print("Product urls of page {} has been scraped.".format(page+1))

    

    try:

        name = driver.find_element_by_xpath('//span[@class="a-size-base-plus a-color-base a-text-normal"]')      # Extracting Name from xpath

        prod_dict['Name'].append(name.text)

    except NoSuchElementException:

        prod_dict['Name'].append('-')
# Out:
#   File "<ipython-input-39-9fb490db5aa2>", line 29
#     try:
#     ^
# SyntaxError: invalid syntax

# %%
driver = webdriver.Chrome('chromedriver.exe')

# %%
url = ''
driver.get(url)

# %%
image = driver.find_element_by_xpath()
image
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e6394369ef32e5888a18a6a5f398bf81", element="50163198-2cc9-463d-ac7f-7b103425a9ff")>

# %%
image.send_keys('fruits')

# %%
im = driver.find_element_by_xpath('//img[@class="rg_i Q4LuWd"]')
im
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="e6394369ef32e5888a18a6a5f398bf81", element="b6f9c188-e403-47ac-a67c-53953e0da6b6")>

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://images.google.com/"
driver.get(url)

time.sleep(5)
#locating the search bar
search_bar=driver.find_element_by_xpath('//input[@class="gLFyf gsfi"]')
search_bar.send_keys('fruits')

time.sleep(3)

# %%
#locating the button and clicking it the search for fruits
btn = driver.find_element_by_id("gsr")
btn.click()

# %%
#creating the empty list
images = []

#scrapping the required details

image=driver.find_elements_by_class_name("rg_i Q4LuWd")            #scraping the images
for i in image:
    images.append(i.get('src'))                    #appending the images

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.naukri.com/"
driver.get(url)
time.sleep(6)

# entering “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore” in “enter the location” field.
search_field_designation=driver.find_element_by_id("qsb-keyword-sugg") #job search bar
search_field_location=driver.find_element_by_id('qsb-location-sugg') #location search bar
search_field_designation.send_keys("Data Analyst")
search_field_location.send_keys("Bangalore")


# clicking the search button
search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()


time.sleep(4)
# creating empty lists for scraping data
job_title=[]
job_location=[]
company_name=[]
experience_required=[]


#scraping the job-titles
titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    if i.text is None :
        job_title.append("--") 
    else:
        job_title.append(i.text)

time.sleep(4)
#scraping the job-location
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    if i.text is None :
        job_location.append("--") 
    else:
        job_location.append(i.text)
        
time.sleep(4)        
#scraping the company_name 
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
company_name[0:2]


time.sleep(4)
#scraping the experience_required 
experience=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience:
    if i.text is None :
            experience_required.append("--") 
    else:
            experience_required.append(i.text)


time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"experience_required":experience_required[0:10],"company_name":company_name[0:10],"job_location":job_location[0:10],
                "job_title":job_title[0:10]})
df
# Out:
#   experience_required                     company_name  \
# 0             0-1 Yrs                        COLLABERA
# 1            5-10 Yrs                    (524 Reviews)
# 2            6-11 Yrs           IBM India Pvt. Limited
# 3             5-8 Yrs                  (10145 Reviews)
# 4             5-8 Yrs  Jana Small Finance Bank Limited
# 5             3-8 Yrs                   (3464 Reviews)
# 6             2-6 Yrs                 Trigent Software
# 7             2-4 Yrs                    (158 Reviews)
# 8            5-10 Yrs                 Trigent Software
# 9             3-6 Yrs                    (158 Reviews)
#
#                   job_location  \
# 0          Bangalore/Bengaluru
# 1          Bangalore/Bengaluru
# 2          Bangalore/Bengaluru
# 3          Bangalore/Bengaluru
# 4          Bangalore/Bengaluru
# 5  Mumbai, Bangalore/Bengaluru
# 6          Bangalore/Bengaluru
# 7          Bangalore/Bengaluru
# 8          Bangalore/Bengaluru
# 9          Bangalore/Bengaluru
#
# ...

# %% [markdown]
# # Q4.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.flipkart.com/"
driver.get(url)

time.sleep(2)
#close log_in window
log_in_pop_up = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')
log_in_pop_up.click()

time.sleep(2)
#locating the search bar
search_bar=driver.find_element_by_class_name("_3704LK")
search_bar.clear()
search_bar.send_keys('Smartphones')

time.sleep(2)
#locating the button and clicking it to search for sneakers
button=driver.find_element_by_class_name('L0Z3Pu')
button.click()

# %%
#creating the empty list
Brand_Name=[]
Smartphone_name=[]
Colour=[]
RAM=[]
Storage_ROM=[]
Primary_Camera=[]
Secondary_Camera=[]
Display_Size=[]
Display_Resolution=[]
Processor=[]
Processor_Cores=[]
Battery_Capacity=[]
Price=[]



time.sleep(3)

# %%
#scrapping the required details

brand=driver.find_elements_by_class_name('_4rR01T')
for i in brand:
    Brand_Name.append(i.text)
name=driver.find_elements_by_class_name("_4rR01T")
for i in name:
    Smartphone_name.append(i.text)
color=driver.find_elements_by_class_name("_4rR01T")
for i in color:
    Colour.append(i.text)
ram=driver.find_elements_by_xpath('//_1xgFaf')
for i in ram:
    RAM.append(i.text)
storage=driver.find_elements_by_class_name("rgWa7D")
for i in storage:
    Storage_ROM.append(i.text)
camera=driver.find_elements_by_class_name("rgWa7D")
for i in camera:
    Primary_Camera.append(i.text)
camera2=driver.find_elements_by_class_name("rgWa7D")
for i in camera2:
    Secondary_Camera.append(i.text)
display=driver.find_elements_by_class_name("rgWa7D")
for i in display:
    Display_Size.append(i.text)
dispRes=driver.find_elements_by_class_name('rgWa7D')
for i in dispRes:
    Display_Resolution.append(i.text)
pros=driver.find_elements_by_class_name("rgWa7D")
for i in pros:
    Processor.append(i.text)
battery=driver.find_elements_by_class_name("rgWa7D")
for i in battery:
    Battery_Capacity.append(i.text)
prices=driver.find_elements_by_class_name('_30jeq3 _1_WHN1')
for i in prices:
    Price.append(i.text)

    
        
        
time.sleep(2)

# %%
        
#creating a dataframe
df=pd.DataFrame({'Brand Name' :Brand_Name[0:24],
                 'Smartphone name': Smartphone_name[0:24],
                 'colour' : Colour[0:24],
                 'RAM' : RAM[0:24],
                 'Storage ROM':Storage_ROM[0:24],
                 'Primary Camera':Primary_Camera[0:24],
                 'Secondary Camera':Secondary_Camera[0:24],
                 'Display Size': Display_Size[0:24],
                 'Display Resolution' : Display_Resolution[0:24],
                 'Processor' : Processor[0:24],
                 'BatteryCapacity' : Battery_Capacity[0:24]
                })
#printing dataframe
df
# Out:
#                                            Brand Name  \
# 0                       realme C20 (Cool Grey, 32 GB)
# 1                       realme C20 (Cool Blue, 32 GB)
# 2                        POCO C3 (Arctic Blue, 32 GB)
# 3   SAMSUNG Galaxy S21 Ultra (Phantom Silver, 256 GB)
# 4                        POCO C3 (Matte Black, 32 GB)
# 5                          POCO M3 (Cool Blue, 64 GB)
# 6                Infinix Smart 5 (Aegean Blue, 32 GB)
# 7            SAMSUNG Galaxy F41 (Fusion Green, 64 GB)
# 8             Infinix Smart 5 (Obsidian Black, 32 GB)
# 9                  Infinix Smart 5 (7° Purple, 32 GB)
# 10             Infinix Smart 5 (Morandi Green, 32 GB)
# 11           SAMSUNG Galaxy F62 (Laser Green, 128 GB)
# 12                            POCO M3 (Yellow, 64 GB)
# 13                       POCO M3 (Power Black, 64 GB)
# 14                         POCO M3 (Cool Blue, 64 GB)
# 15            SAMSUNG Galaxy F62 (Laser Blue, 128 GB)
# ...

# %% [markdown]
# ## Q5

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/ref=nav_logo"
driver.get(url)


#creating the empty list
Title=[]
Ratings=[]
price=[]

time.sleep(2)
#locating the search bar
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys("laptops")                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')       # Locating search_button by xpath
search_button.click()    

time.sleep(2)
#locating the core i7 filter
filter_button=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in filter_button:
    if i.text=='Intel Core i7':
        i.click()
        break
        
        
#Scrapping Titles
titles=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in titles[:10]:
    Title.append(i.text)
    
    
#scrapping Price
prices=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in prices[:10]:
    price.append(i.text)

#locating Ratings
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")#collecting urls of all the laptop
UR=[]
for i in urls[:10]:
    UR.append(i.get_attribute('href'))#getting the url of first 10 laptops
for url in UR:#loop for every laptop in the list
    driver.get(url)
    try:                  #exception handling for nosuchelementexception                                                    #click the rating link found
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")#locating the rating
        Ratings.append(rating.text)#appending the ratings in Ratings list
        
    except NoSuchElementException:
        Ratings.append("NO rating")#appending the No rating if no rating is there
        
#creating a dataframe
df=pd.DataFrame({'Title':Title,
                'Price':price,
                'Ratings':Ratings})
#printing dataframe
df
